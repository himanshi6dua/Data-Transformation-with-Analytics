# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from fuzzywuzzy import process, fuzz

# %%
df = pd.read_csv(r'C:\Users\HimanshiDua\Documents\DWM\abc2.csv')
df
# Out:
#   Script Code                      Script Description  \
# 0  AMBP120SIA  AMBP 120 SITE INSPECTION AND ASSURANCE
# 1  AMBP120SIA  AMBP 120 SITE INSPECTION AND ASSURANCE
# 2  AMBP120SIA  AMBP 120 SITE INSPECTION AND ASSURANCE
# 3  AMBP120SIA  AMBP 120 SITE INSPECTION AND ASSURANCE
# 4  AMBP120SIA  AMBP 120 SITE INSPECTION AND ASSURANCE
# 5  AMBP120SIA  AMBP 120 SITE INSPECTION AND ASSURANCE
#
#                            Script Question
# 0                What is pressure reading?
# 1               Note the pressure reading?
# 2  Check if the Fan and Pumps are working.
# 3    Check if the Fan & Pumps are working.
# 4            What is the room temperature?
# 5            What is the Room temperature?

# %%
df.loc[:,'Script Question_copy'] = df['Script Question']

compare = pd.MultiIndex.from_product([df['Script Question'],
                                      df['Script Question_copy']]).to_series()

def metrics(tup):
    return pd.Series([fuzz.ratio(*tup),
                      fuzz.token_sort_ratio(*tup)],
                     ['ratio', 'token'])

ratio=compare.apply(metrics)
ratio.reset_index(inplace=True)
ratio
# Out:
#                                     level_0  \
# 0                 What is pressure reading?
# 1                 What is pressure reading?
# 2                 What is pressure reading?
# 3                 What is pressure reading?
# 4                 What is pressure reading?
# 5                 What is pressure reading?
# 6                Note the pressure reading?
# 7                Note the pressure reading?
# 8                Note the pressure reading?
# 9                Note the pressure reading?
# 10               Note the pressure reading?
# 11               Note the pressure reading?
# 12  Check if the Fan and Pumps are working.
# 13  Check if the Fan and Pumps are working.
# 14  Check if the Fan and Pumps are working.
# 15  Check if the Fan and Pumps are working.
# 16  Check if the Fan and Pumps are working.
# 17  Check if the Fan and Pumps are working.
# 18    Check if the Fan & Pumps are working.
# 19    Check if the Fan & Pumps are working.
# 20    Check if the Fan & Pumps are working.
# 21    Check if the Fan & Pumps are working.
# 22    Check if the Fan & Pumps are working.
# 23    Check if the Fan & Pumps are working.
# 24            What is the room temperature?
# 25            What is the room temperature?
# 26            What is the room temperature?
# 27            What is the room temperature?
# 28            What is the room temperature?
# 29            What is the room temperature?
# 30            What is the Room temperature?
# 31            What is the Room temperature?
# 32            What is the Room temperature?
# 33            What is the Room temperature?
# 34            What is the Room temperature?
# 35            What is the Room temperature?
#
#                                     level_1  ratio  token
# 0                 What is pressure reading?    100    100
# 1                Note the pressure reading?     75     78
# 2   Check if the Fan and Pumps are working.     38     26
# 3     Check if the Fan & Pumps are working.     39     24
# 4             What is the room temperature?     52     58
# 5             What is the Room temperature?     52     58
# 6                 What is pressure reading?     78     78
# 7                Note the pressure reading?    100    100
# 8   Check if the Fan and Pumps are working.     46     38
# 9     Check if the Fan & Pumps are working.     48     34
# 10            What is the room temperature?     44     45
# 11            What is the Room temperature?     44     45
# 12                What is pressure reading?     38     29
# 13               Note the pressure reading?     43     38
# 14  Check if the Fan and Pumps are working.    100    100
# 15    Check if the Fan & Pumps are working.     95     94
# 16            What is the room temperature?     41     27
# 17            What is the Room temperature?     41     27
# 18                What is pressure reading?     39     28
# 19               Note the pressure reading?     44     34
# 20  Check if the Fan and Pumps are working.     95     94
# 21    Check if the Fan & Pumps are working.    100    100
# 22            What is the room temperature?     42     29
# 23            What is the Room temperature?     42     29
# 24                What is pressure reading?     52     58
# 25               Note the pressure reading?     44     45
# 26  Check if the Fan and Pumps are working.     41     30
# 27    Check if the Fan & Pumps are working.     42     32
# 28            What is the room temperature?    100    100
# 29            What is the Room temperature?     97    100
# 30                What is pressure reading?     48     58
# 31               Note the pressure reading?     40     45
# 32  Check if the Fan and Pumps are working.     41     30
# 33    Check if the Fan & Pumps are working.     42     32
# 34            What is the room temperature?     97    100
# 35            What is the Room temperature?    100    100

# %%
ratio=ratio.rename(columns={'level_0': 'Input Question','level_1':'Output Result'})
ratio
# Out:
#                              Input Question  \
# 0                 What is pressure reading?
# 1                 What is pressure reading?
# 2                 What is pressure reading?
# 3                 What is pressure reading?
# 4                 What is pressure reading?
# 5                 What is pressure reading?
# 6                Note the pressure reading?
# 7                Note the pressure reading?
# 8                Note the pressure reading?
# 9                Note the pressure reading?
# 10               Note the pressure reading?
# 11               Note the pressure reading?
# 12  Check if the Fan and Pumps are working.
# 13  Check if the Fan and Pumps are working.
# 14  Check if the Fan and Pumps are working.
# 15  Check if the Fan and Pumps are working.
# 16  Check if the Fan and Pumps are working.
# 17  Check if the Fan and Pumps are working.
# 18    Check if the Fan & Pumps are working.
# 19    Check if the Fan & Pumps are working.
# 20    Check if the Fan & Pumps are working.
# 21    Check if the Fan & Pumps are working.
# 22    Check if the Fan & Pumps are working.
# 23    Check if the Fan & Pumps are working.
# 24            What is the room temperature?
# 25            What is the room temperature?
# 26            What is the room temperature?
# 27            What is the room temperature?
# 28            What is the room temperature?
# 29            What is the room temperature?
# 30            What is the Room temperature?
# 31            What is the Room temperature?
# 32            What is the Room temperature?
# 33            What is the Room temperature?
# 34            What is the Room temperature?
# 35            What is the Room temperature?
#
#                               Output Result  ratio  token
# 0                 What is pressure reading?    100    100
# 1                Note the pressure reading?     75     78
# 2   Check if the Fan and Pumps are working.     38     26
# 3     Check if the Fan & Pumps are working.     39     24
# 4             What is the room temperature?     52     58
# 5             What is the Room temperature?     52     58
# 6                 What is pressure reading?     78     78
# 7                Note the pressure reading?    100    100
# 8   Check if the Fan and Pumps are working.     46     38
# 9     Check if the Fan & Pumps are working.     48     34
# 10            What is the room temperature?     44     45
# 11            What is the Room temperature?     44     45
# 12                What is pressure reading?     38     29
# 13               Note the pressure reading?     43     38
# 14  Check if the Fan and Pumps are working.    100    100
# 15    Check if the Fan & Pumps are working.     95     94
# 16            What is the room temperature?     41     27
# 17            What is the Room temperature?     41     27
# 18                What is pressure reading?     39     28
# 19               Note the pressure reading?     44     34
# 20  Check if the Fan and Pumps are working.     95     94
# 21    Check if the Fan & Pumps are working.    100    100
# 22            What is the room temperature?     42     29
# 23            What is the Room temperature?     42     29
# 24                What is pressure reading?     52     58
# 25               Note the pressure reading?     44     45
# 26  Check if the Fan and Pumps are working.     41     30
# 27    Check if the Fan & Pumps are working.     42     32
# 28            What is the room temperature?    100    100
# 29            What is the Room temperature?     97    100
# 30                What is pressure reading?     48     58
# 31               Note the pressure reading?     40     45
# 32  Check if the Fan and Pumps are working.     41     30
# 33    Check if the Fan & Pumps are working.     42     32
# 34            What is the room temperature?     97    100
# 35            What is the Room temperature?    100    100

# %%
ratio=ratio.sort_values(['Input Question','ratio'],ascending=[False,False])
ratio
# Out:
#                              Input Question  \
# 28            What is the room temperature?
# 29            What is the room temperature?
# 24            What is the room temperature?
# 25            What is the room temperature?
# 27            What is the room temperature?
# 26            What is the room temperature?
# 35            What is the Room temperature?
# 34            What is the Room temperature?
# 30            What is the Room temperature?
# 33            What is the Room temperature?
# 32            What is the Room temperature?
# 31            What is the Room temperature?
# 0                 What is pressure reading?
# 1                 What is pressure reading?
# 4                 What is pressure reading?
# 5                 What is pressure reading?
# 3                 What is pressure reading?
# 2                 What is pressure reading?
# 7                Note the pressure reading?
# 6                Note the pressure reading?
# 9                Note the pressure reading?
# 8                Note the pressure reading?
# 10               Note the pressure reading?
# 11               Note the pressure reading?
# 14  Check if the Fan and Pumps are working.
# 15  Check if the Fan and Pumps are working.
# 13  Check if the Fan and Pumps are working.
# 16  Check if the Fan and Pumps are working.
# 17  Check if the Fan and Pumps are working.
# 12  Check if the Fan and Pumps are working.
# 21    Check if the Fan & Pumps are working.
# 20    Check if the Fan & Pumps are working.
# 19    Check if the Fan & Pumps are working.
# 22    Check if the Fan & Pumps are working.
# 23    Check if the Fan & Pumps are working.
# 18    Check if the Fan & Pumps are working.
#
#                               Output Result  ratio  token
# 28            What is the room temperature?    100    100
# 29            What is the Room temperature?     97    100
# 24                What is pressure reading?     52     58
# 25               Note the pressure reading?     44     45
# 27    Check if the Fan & Pumps are working.     42     32
# 26  Check if the Fan and Pumps are working.     41     30
# 35            What is the Room temperature?    100    100
# 34            What is the room temperature?     97    100
# 30                What is pressure reading?     48     58
# 33    Check if the Fan & Pumps are working.     42     32
# 32  Check if the Fan and Pumps are working.     41     30
# 31               Note the pressure reading?     40     45
# 0                 What is pressure reading?    100    100
# 1                Note the pressure reading?     75     78
# 4             What is the room temperature?     52     58
# 5             What is the Room temperature?     52     58
# 3     Check if the Fan & Pumps are working.     39     24
# 2   Check if the Fan and Pumps are working.     38     26
# 7                Note the pressure reading?    100    100
# 6                 What is pressure reading?     78     78
# 9     Check if the Fan & Pumps are working.     48     34
# 8   Check if the Fan and Pumps are working.     46     38
# 10            What is the room temperature?     44     45
# 11            What is the Room temperature?     44     45
# 14  Check if the Fan and Pumps are working.    100    100
# 15    Check if the Fan & Pumps are working.     95     94
# 13               Note the pressure reading?     43     38
# 16            What is the room temperature?     41     27
# 17            What is the Room temperature?     41     27
# 12                What is pressure reading?     38     29
# 21    Check if the Fan & Pumps are working.    100    100
# 20  Check if the Fan and Pumps are working.     95     94
# 19               Note the pressure reading?     44     34
# 22            What is the room temperature?     42     29
# 23            What is the Room temperature?     42     29
# 18                What is pressure reading?     39     28

# %%
df.loc[:,'Script Question_copy'] = df['Script Question']

compare = pd.MultiIndex.from_product([df['Script Question'],
                                      df['Script Question_copy']]).to_series()

def metrics(tup):
    return pd.Series([fuzz.ratio(*tup),
                      fuzz.token_set_ratio(*tup)],
                     ['ratio', 'token'])

ratio=compare.apply(metrics)
ratio.reset_index(inplace=True)
ratio
# Out:
#                                     level_0  \
# 0                 What is pressure reading?
# 1                 What is pressure reading?
# 2                 What is pressure reading?
# 3                 What is pressure reading?
# 4                 What is pressure reading?
# 5                 What is pressure reading?
# 6                Note the pressure reading?
# 7                Note the pressure reading?
# 8                Note the pressure reading?
# 9                Note the pressure reading?
# 10               Note the pressure reading?
# 11               Note the pressure reading?
# 12  Check if the Fan and Pumps are working.
# 13  Check if the Fan and Pumps are working.
# 14  Check if the Fan and Pumps are working.
# 15  Check if the Fan and Pumps are working.
# 16  Check if the Fan and Pumps are working.
# 17  Check if the Fan and Pumps are working.
# 18    Check if the Fan & Pumps are working.
# 19    Check if the Fan & Pumps are working.
# 20    Check if the Fan & Pumps are working.
# 21    Check if the Fan & Pumps are working.
# 22    Check if the Fan & Pumps are working.
# 23    Check if the Fan & Pumps are working.
# 24            What is the room temperature?
# 25            What is the room temperature?
# 26            What is the room temperature?
# 27            What is the room temperature?
# 28            What is the room temperature?
# 29            What is the room temperature?
# 30            What is the Room temperature?
# 31            What is the Room temperature?
# 32            What is the Room temperature?
# 33            What is the Room temperature?
# 34            What is the Room temperature?
# 35            What is the Room temperature?
#
#                                     level_1  ratio  token
# 0                 What is pressure reading?    100    100
# 1                Note the pressure reading?     75     80
# 2   Check if the Fan and Pumps are working.     38     26
# 3     Check if the Fan & Pumps are working.     39     24
# 4             What is the room temperature?     52     58
# 5             What is the Room temperature?     52     58
# 6                 What is pressure reading?     78     80
# 7                Note the pressure reading?    100    100
# 8   Check if the Fan and Pumps are working.     46     41
# 9     Check if the Fan & Pumps are working.     48     37
# 10            What is the room temperature?     44     53
# 11            What is the Room temperature?     44     53
# 12                What is pressure reading?     38     29
# 13               Note the pressure reading?     43     44
# 14  Check if the Fan and Pumps are working.    100    100
# 15    Check if the Fan & Pumps are working.     95    100
# 16            What is the room temperature?     41     30
# 17            What is the Room temperature?     41     30
# 18                What is pressure reading?     39     28
# 19               Note the pressure reading?     44     41
# 20  Check if the Fan and Pumps are working.     95    100
# 21    Check if the Fan & Pumps are working.    100    100
# 22            What is the room temperature?     42     32
# 23            What is the Room temperature?     42     32
# 24                What is pressure reading?     52     58
# 25               Note the pressure reading?     44     53
# 26  Check if the Fan and Pumps are working.     41     30
# 27    Check if the Fan & Pumps are working.     42     29
# 28            What is the room temperature?    100    100
# 29            What is the Room temperature?     97    100
# 30                What is pressure reading?     48     58
# 31               Note the pressure reading?     40     53
# 32  Check if the Fan and Pumps are working.     41     30
# 33    Check if the Fan & Pumps are working.     42     29
# 34            What is the room temperature?     97    100
# 35            What is the Room temperature?    100    100

# %%
df.loc[:,'Script Question_copy'] = df['Script Question']

compare = pd.MultiIndex.from_product([df['Script Question'],
                                      df['Script Question_copy']]).to_series()

def metrics(tup):
    return pd.Series([fuzz.ratio(*tup),
                      fuzz.partial_ratio(*tup)],
                     ['ratio', 'token'])

ratio=compare.apply(metrics)
ratio.reset_index(inplace=True)
ratio
# Out:
#                                     level_0  \
# 0                 What is pressure reading?
# 1                 What is pressure reading?
# 2                 What is pressure reading?
# 3                 What is pressure reading?
# 4                 What is pressure reading?
# 5                 What is pressure reading?
# 6                Note the pressure reading?
# 7                Note the pressure reading?
# 8                Note the pressure reading?
# 9                Note the pressure reading?
# 10               Note the pressure reading?
# 11               Note the pressure reading?
# 12  Check if the Fan and Pumps are working.
# 13  Check if the Fan and Pumps are working.
# 14  Check if the Fan and Pumps are working.
# 15  Check if the Fan and Pumps are working.
# 16  Check if the Fan and Pumps are working.
# 17  Check if the Fan and Pumps are working.
# 18    Check if the Fan & Pumps are working.
# 19    Check if the Fan & Pumps are working.
# 20    Check if the Fan & Pumps are working.
# 21    Check if the Fan & Pumps are working.
# 22    Check if the Fan & Pumps are working.
# 23    Check if the Fan & Pumps are working.
# 24            What is the room temperature?
# 25            What is the room temperature?
# 26            What is the room temperature?
# 27            What is the room temperature?
# 28            What is the room temperature?
# 29            What is the room temperature?
# 30            What is the Room temperature?
# 31            What is the Room temperature?
# 32            What is the Room temperature?
# 33            What is the Room temperature?
# 34            What is the Room temperature?
# 35            What is the Room temperature?
#
#                                     level_1  ratio  token
# 0                 What is pressure reading?    100    100
# 1                Note the pressure reading?     75     83
# 2   Check if the Fan and Pumps are working.     38     46
# 3     Check if the Fan & Pumps are working.     39     46
# 4             What is the room temperature?     52     52
# 5             What is the Room temperature?     52     48
# 6                 What is pressure reading?     78     83
# 7                Note the pressure reading?    100    100
# 8   Check if the Fan and Pumps are working.     46     44
# 9     Check if the Fan & Pumps are working.     48     46
# 10            What is the room temperature?     44     46
# 11            What is the Room temperature?     44     46
# 12                What is pressure reading?     38     46
# 13               Note the pressure reading?     43     44
# 14  Check if the Fan and Pumps are working.    100    100
# 15    Check if the Fan & Pumps are working.     95     92
# 16            What is the room temperature?     41     48
# 17            What is the Room temperature?     41     48
# 18                What is pressure reading?     39     46
# 19               Note the pressure reading?     44     46
# 20  Check if the Fan and Pumps are working.     95     92
# 21    Check if the Fan & Pumps are working.    100    100
# 22            What is the room temperature?     42     48
# 23            What is the Room temperature?     42     48
# 24                What is pressure reading?     52     52
# 25               Note the pressure reading?     44     46
# 26  Check if the Fan and Pumps are working.     41     48
# 27    Check if the Fan & Pumps are working.     42     48
# 28            What is the room temperature?    100    100
# 29            What is the Room temperature?     97     97
# 30                What is pressure reading?     48     48
# 31               Note the pressure reading?     40     46
# 32  Check if the Fan and Pumps are working.     41     48
# 33    Check if the Fan & Pumps are working.     42     48
# 34            What is the room temperature?     97     97
# 35            What is the Room temperature?    100    100

# %% [markdown]
# we can demonstrate 4 methods - fuzz.ratio, fuzz.partial_ratio, fuzz.token_sort_ratio and fuzz.token_set_ratio.
#
#
# # Token Sort Ratio
# fuzz.token_sort_ratio("if possible calculate the reading", "calculate the reading if possible")
# 100
#
# This gives 100 as every word is same, irrespective of the position
#
# # Token Set Ratio
# fuzz.token_sort_ratio("geeks for geeks", "geeks for for geeks")
# 88
#  fuzz.token_set_ratio("geeks for geeks", "geeks for for geeks")
# 100
#
# Score comes 100 in second case because token_set_ratio considers duplicate words as a single word.
#
#  # Partial Ratio
# fuzz.partial_ratio("what is the pressure reading", "what is the pressure reading?")
# 100
#
# checks only first string , if its found, then results 100%
